# %% [markdown]
# ## Preparacion de los Datos

# %% [markdown]
# ### 1) Cargar el dataset

# %%
import pandas as pd

# Cargar el archivo
df = pd.read_csv("telecomx_clean.csv")

# Verificar estructura
df.head()
# Out:
#     ClienteID  Churn  Genero  Adulto_Mayor  Tiene_Pareja  Tiene_Dependientes  \
# 0  0002-ORFBO      0  Female             0             1                   1
# 1  0003-MKNFE      0    Male             0             0                   0
# 2  0004-TLHLJ      1    Male             0             0                   0
# 3  0011-IGKFF      1    Male             1             1                   0
# 4  0013-EXCHZ      1  Female             1             1                   0
#
#    Antiguedad_Meses  Servicio_Telefono Lineas_Multiples Servicio_Internet  \
# 0                 9                  1               No               DSL
# 1                 9                  1              Yes               DSL
# 2                 4                  1               No       Fiber optic
# 3                13                  1               No       Fiber optic
# 4                 3                  1               No       Fiber optic
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 23 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   ClienteID               7043 non-null   object
#  1   Churn                   7043 non-null   int64
#  2   Genero                  7043 non-null   object
#  3   Adulto_Mayor            7043 non-null   int64
#  4   Tiene_Pareja            7043 non-null   int64
#  5   Tiene_Dependientes      7043 non-null   int64
#  6   Antiguedad_Meses        7043 non-null   int64
#  7   Servicio_Telefono       7043 non-null   int64
#  8   Lineas_Multiples        7043 non-null   object
#  9   Servicio_Internet       7043 non-null   object
#  10  Seguridad_Online        7043 non-null   object
#  11  Backup_Online           7043 non-null   object
#  12  Proteccion_Dispositivo  7043 non-null   object
#  13  Soporte_Tecnico         7043 non-null   object
# ...

# %%
df.describe()
# Out:
#              Churn  Adulto_Mayor  Tiene_Pareja  Tiene_Dependientes  \
# count  7043.000000   7043.000000   7043.000000         7043.000000
# mean      0.265370      0.162147      0.483033            0.299588
# std       0.441561      0.368612      0.499748            0.458110
# min       0.000000      0.000000      0.000000            0.000000
# 25%       0.000000      0.000000      0.000000            0.000000
# 50%       0.000000      0.000000      0.000000            0.000000
# 75%       1.000000      0.000000      1.000000            1.000000
# max       1.000000      1.000000      1.000000            1.000000
#
#        Antiguedad_Meses  Servicio_Telefono  Factura_Electronica  \
# count       7043.000000        7043.000000          7043.000000
# mean          32.371149           0.903166             0.592219
# std           24.559481           0.295752             0.491457
# min            0.000000           0.000000             0.000000
# ...

# %%
df["Churn"].value_counts()
# Out:
# Churn
# 0    5174
# 1    1869
# Name: count, dtype: int64

# %% [markdown]
# ### 2) Eliminación de Columnas Irrelevantes

# %%
df = df.drop(columns=["ClienteID"])

# Verificamos
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 22 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Churn                   7043 non-null   int64
#  1   Genero                  7043 non-null   object
#  2   Adulto_Mayor            7043 non-null   int64
#  3   Tiene_Pareja            7043 non-null   int64
#  4   Tiene_Dependientes      7043 non-null   int64
#  5   Antiguedad_Meses        7043 non-null   int64
#  6   Servicio_Telefono       7043 non-null   int64
#  7   Lineas_Multiples        7043 non-null   object
#  8   Servicio_Internet       7043 non-null   object
#  9   Seguridad_Online        7043 non-null   object
#  10  Backup_Online           7043 non-null   object
#  11  Proteccion_Dispositivo  7043 non-null   object
#  12  Soporte_Tecnico         7043 non-null   object
#  13  Streaming_TV            7043 non-null   object
# ...

# %%
df["Churn"].value_counts(normalize=True) # Proporción de clientes que abandonan
# Out:
# Churn
# 0    0.73463
# 1    0.26537
# Name: proportion, dtype: float64

# %% [markdown]
# ### 3) Embeddings

# %% [markdown]
# #### 3.1) Analisis de variables

# %%
pd.unique(df["Churn"])
# Out:
# array([0, 1])

# %%
pd.unique(df["Genero"])
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
pd.unique(df["Adulto_Mayor"])
# Out:
# array([0, 1])

# %%
pd.unique(df["Tiene_Pareja"])
# Out:
# array([1, 0])

# %%
pd.unique(df["Tiene_Dependientes"])
# Out:
# array([1, 0])

# %%
pd.unique(df["Antiguedad_Meses"])
# Out:
# array([ 9,  4, 13,  3, 71, 63,  7, 65, 54, 72,  5, 56, 34,  1, 45, 50, 23,
#        55, 26, 69, 37, 49, 66, 67, 20, 43, 59, 12, 27,  2, 25, 29, 14, 35,
#        64, 39, 40, 11,  6, 30, 70, 57, 58, 16, 32, 33, 10, 21, 61, 15, 44,
#        22, 24, 19, 47, 62, 46, 52,  8, 60, 48, 28, 41, 53, 68, 31, 36, 17,
#        18, 51, 38, 42,  0])

# %%
pd.unique(df["Servicio_Telefono"])
# Out:
# array([1, 0])

# %%
pd.unique(df["Lineas_Multiples"])
# Out:
# array(['No', 'Yes', 'No phone service'], dtype=object)

# %%
pd.unique(df["Servicio_Internet"])
# Out:
# array(['DSL', 'Fiber optic', 'No'], dtype=object)

# %%
pd.unique(df["Seguridad_Online"])
# Out:
# array(['No', 'Yes', 'No internet service'], dtype=object)

# %%
pd.unique(df["Backup_Online"])
# Out:
# array(['Yes', 'No', 'No internet service'], dtype=object)

# %%
pd.unique(df["Proteccion_Dispositivo"])
# Out:
# array(['No', 'Yes', 'No internet service'], dtype=object)

# %%
pd.unique(df["Soporte_Tecnico"])
# Out:
# array(['Yes', 'No', 'No internet service'], dtype=object)

# %%
pd.unique(df["Streaming_TV"])
# Out:
# array(['Yes', 'No', 'No internet service'], dtype=object)

# %%
pd.unique(df["Streaming_Peliculas"])
# Out:
# array(['No', 'Yes', 'No internet service'], dtype=object)

# %%
pd.unique(df["Tipo_Contrato"])
# Out:
# array(['One year', 'Month-to-month', 'Two year'], dtype=object)

# %%
pd.unique(df["Factura_Electronica"])
# Out:
# array([1, 0])

# %%
pd.unique(df["Metodo_Pago"])
# Out:
# array(['Mailed check', 'Electronic check', 'Credit card (automatic)',
#        'Bank transfer (automatic)'], dtype=object)

# %%
pd.unique(df["Cargo_Mensual"])
# Out:
# array([65.6 , 59.9 , 73.9 , ..., 91.75, 68.8 , 67.85], shape=(1585,))

# %%
pd.unique(df["Cargo_Total"])
# Out:
# array([ 593.3 ,  542.4 ,  280.85, ...,  742.9 , 4627.65, 3707.6 ],
#       shape=(6531,))

# %%
pd.unique(df["Cuentas_Diarias"])
# Out:
# array([2.18666667, 1.99666667, 2.46333333, ..., 3.05833333, 2.29333333,
#        2.26166667], shape=(1585,))

# %%
pd.unique(df["Cantidad_Servicios"])
# Out:
# array([3, 1, 4, 2, 6, 0, 5])
